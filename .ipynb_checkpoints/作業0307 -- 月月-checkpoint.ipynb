# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
## What is your werewolf name ?

# %%
from IPython.display import display,HTML,Markdown,Image,YouTubeVideo

# %%
MoonMoon = Image('月月.jpg')

# %%
display(MoonMoon)

# %%
lastname = input("請輸入你的英文姓氏: ")
# Out:
# 請輸入你的英文姓氏: 4

# %%
firstname = input("請輸入你的英文名字:")
# Out:
# 請輸入你的英文名字:5

# %%
def wolf_name():
    lastname = input("請輸入你的英文姓氏:")
    firstname = input("請輸入你的英文名字:")
    
    
    if firstname[0] == "A":
        w_n = "White"
    elif firstname[0] == "B":
        w_n = "Lone"
    elif firstname[0] == "C":
        w_n = "Ravenous"
    elif firstname[0] == "D":
        w_n = "Magic"
    elif firstname[0] == "E":
        w_n = "Ancient"
    elif firstname[0] == "F":
        w_n = "ebony"
    elif firstname[0] == "G":
        w_n = "Dark"
    elif firstname[0] == "H":
        w_n = "Savage"
    elif firstname[0] == "I":
        w_n = "Regal"
    elif firstname[0] == "J":
        w_n = "Rogue"
    elif firstname[0] == "K":
        w_n = "Scarlet"
    elif firstname[0] == "L":
        w_n = "Fierce"
    elif firstname[0] == "M":
        w_n = "Alpha"
    elif firstname[0] == "N":
        w_n = "Beautiful"
    elif firstname[0] == "O":
        w_n = "blood"
    elif firstname[0] == "P":
        w_n = "Moon"
    elif firstname[0] == "Q":
        w_n = "Loyal"
    elif firstname[0] == "R":
        w_n = "Scarred"
    elif firstname[0] == "S":
        w_n = "Grey"
    elif firstname[0] == "T":
        w_n = "Mystic"
    elif firstname[0] == "U":
        w_n = "Prime"
    elif firstname[0] == "V":
        w_n = "Graceful"
    elif firstname[0] == "W":
        w_n = "Majestic"
    elif firstname[0] == "X":
        w_n = "Wild"
    elif firstname[0] == "Y":
        w_n = "Vengeful"
    elif firstname[0] == "Z":
        w_n = "Creul"
    else:
        print("你的名字好像打錯囉~")
        firstname = input("請輸入你的英文名字:")
    
    if firstname[0] == "A":
        w_n2 = "Hunter"
    elif firstname[0] == "B":
        w_n2 = "Demon"
    elif firstname[0] == "C":
        w_n2 = "Howler"
    elif firstname[0] == "D":
        w_n2 = "Rain"
    elif firstname[0] == "E":
        w_n2 = "Red"
    elif firstname[0] == "F":
        w_n2 = "Shadow"
    elif firstname[0] == "G":
        w_n2 = "Storm"
    elif firstname[0] == "H":
        w_n2 = "Beast"
    elif firstname[0] == "I":
        w_n2 = "Bane"
    elif firstname[0] == "J":
        w_n2 = "Dagger"
    elif firstname[0] == "K":
        w_n2 = "Hound"
    elif firstname[0] == "L":
        w_n2 = "Fang"
    elif firstname[0] == "M":
        w_n2 = "Claw"
    elif firstname[0] == "N":
        w_n2 = "Wolf"
    elif firstname[0] == "O":
        w_n2 = "Crescent"
    elif firstname[0] == "P":
        w_n2 = "Paw"
    elif firstname[0] == "Q":
        w_n2 = "Lupus"
    elif firstname[0] == "R":
        w_n2 = "Fire"
    elif firstname[0] == "S":
        w_n2 = "Temptress"
    elif firstname[0] == "T":
        w_n2 = "Warrior"
    elif firstname[0] == "U":
        w_n2 = "Rage"
    elif firstname[0] == "V":
        w_n2 = "Thorn"
    elif firstname[0] == "W":
        w_n2 = "Moon"
    elif firstname[0] == "X":
        w_n2 = "Lupe"
    elif firstname[0] == "Y":
        w_n2 = "Vixen"
    elif firstname[0] == "Z":
        w_n2 = "Omega"
    else:
        print("姓氏的部分好像打錯囉~")
        lastname = input("請輸入你的英文姓氏:")
    
    print("你的狼族姓名是" + str(w_n)+ " " +str(w_n2))

# %%
wolf_name()
# Out:
# 請輸入你的英文姓氏:Chen
# 請輸入你的英文名字:Jia-wei
# 你的狼族姓名是Rogue Dagger
